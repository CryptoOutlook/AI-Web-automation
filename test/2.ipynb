# %% [markdown]
# ### Finacle RD Account opening

# %%
from PIL import ImageGrab
import os
# os.environ['DISPLAY'] = ':1'
import pyautogui
import PIL
import time

# %%
def tab(times: int = 1, interval: float = 0.3) -> None:
    pyautogui.press(keys='tab', presses=times, interval=0.3)

# %%
os.system('wslview https://www.google.com')
time.sleep(5)
tab(3)

# %%
time.sleep(3)
pyautogui.displayMousePosition()
# Out:
# Press Ctrl-C to quit.
# ...

# %%
time.sleep(3)
pyautogui.hotkey('alt', 'tab')
pyautogui.moveTo(534, 341, 2)
pyautogui.drag(100, 2, button='left')
pyautogui.click(clicks=3)
