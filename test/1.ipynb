# %% [markdown]
# ### Imports

# %%
from PIL import ImageGrab
import os
os.environ['DISPLAY'] = ':1'
import pyautogui
import PIL
import time

# %%
pyautogui.displayMousePosition(2,2)
# Out:
# Press Ctrl-C to quit.
# xOffset: 2 yOffset: 2
# X:  958 Y:  538 RGB: (  0, 170, 22
# ...

# %%
os.system("vncviewer 192.168.0.53:0")
# Out:
# sh: 1: vncviewer: not found
# 32512

# %%
pyautogui.onScreen(0, 0)
pyautogui.size()
# Out:
# Size(width=1920, height=1080)

# %%
pyautogui.onScreen(1919, 1079)
# Out:
# True

# %%
pyautogui.moveTo(100, 200, 5)

# %%
pyautogui.press(keys='up', presses=4, interval=0.3)

# %%
pyautogui.press(keys='down', presses=4, interval=0.3)

# %%
pyautogui.write('wslview https://google.com')
pyautogui.press('enter')

# %%
pyautogui.write('xdg-open https://www.google.com')

# %%
pyautogui.press('enter')
